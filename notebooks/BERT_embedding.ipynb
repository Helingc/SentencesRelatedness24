# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
from scipy.stats import spearmanr, pearsonr
from scipy import spatial
from transformers import BartTokenizer, BartModel
import torch
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
PATH = os.path.join("..", "data", "raw")

df_train = pd.read_csv(os.path.join(PATH, 'eng_train.csv'))
df_train["Split_Text"] = df_train["Text"].apply(lambda x: x.replace("\n", " "))
df_train['Split_Text'] = df_train['Split_Text'].apply(lambda x: x.split("\r"))
df_train['Split_Text'] = df_train['Split_Text'].apply(lambda x: [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in x])

df_train["sen_1"] = df_train["Split_Text"].apply(lambda x: x[0])
df_train["sen_2"] = df_train["Split_Text"].apply(lambda x: x[1])
df_train.drop(["Split_Text"], axis=1, inplace=True)
df_train.head()

# For testing puposes:
# df_train = df_train.iloc[[212, 23,1578, 4000, 1230, 1, 2 ,4, 4500]]
# Out:
#            PairID                                               Text  Score  \
# 0  ENG-train-0000  It that happens, just pull the plug.\r\nif tha...    1.0
# 1  ENG-train-0001  A black dog running through water.\r\nA black ...    1.0
# 2  ENG-train-0002  I've been searchingthe entire abbey for you.\r...    1.0
# 3  ENG-train-0003  If he is good looking and has a good personali...    1.0
# 4  ENG-train-0004  She does not hate you, she is just annoyed wit...    1.0
#
#                                                sen_1  \
# 0                It that happens just pull the plug
# 1                 A black dog running through water
# 2       I ve been searchingthe entire abbey for you
# 3  If he is good looking and has a good personali...
# 4  She does not hate you she is just annoyed with...
#
#                                                sen_2
# 0           if that ever happens just pull the plug
# 1         A black dog is running through some water
# 2            I m looking for you all over the abbey
# 3   If he s good looking and a good personality h...
# 4          She doesn t hate you she is just annoyed

# %% [markdown]
# # 1. Simple BART without data preprocessing

# %%
# Load BART tokenizer and model
# ~ 1.6GB download
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
model = BartModel.from_pretrained("facebook/bart-large-cnn")

# Example sentences
sentence_i = "This is the first sentence."

def get_bart_embeddings(sentence):
    # Tokenize and encode the sentences
    tokens_i = tokenizer(sentence, return_tensors="pt")

    # Get BART embeddings
    with torch.no_grad():
        embeddings_i = model(**tokens_i).last_hidden_state.mean(dim=1)

    # Convert embeddings to numpy arrays
    embeddings_i = embeddings_i.numpy()
    return list(embeddings_i[0])

# Get embeddings for the example sentences
embeddings_i = get_bart_embeddings(sentence_i)
embeddings_i
# Out:
# [0.211976,
#  -0.13496348,
#  -0.15495235,
#  0.06478819,
#  -0.145485,
#  -0.043188006,
#  -0.47269195,
#  0.12503225,
#  -0.015076393,
#  -0.269134,
#  0.07640724,
#  -0.26634884,
#  -0.4174175,
#  -0.04174583,
#  -0.28923738,
#  -0.45047167,
#  -0.340972,
#  -0.124985576,
#  0.1844579,
#  -0.09033446,
#  3.7348526,
#  -0.11281986,
#  0.33048213,
#  -0.4693795,
#  -0.34390354,
#  -0.09340204,
#  0.08813639,
#  -0.25314727,
#  -0.15623412,
#  -0.22234684,
#  -0.005976487,
#  -0.17191175,
#  -0.4435841,
#  -0.019253146,
#  0.057688423,
#  -0.1955575,
#  -0.23122324,
#  0.3476895,
#  -0.12556855,
#  -0.085818246,
#  0.21792093,
#  -0.8871238,
#  -0.10941392,
#  0.39390504,
#  -0.10595424,
#  -0.3309575,
#  0.013458585,
#  0.12769294,
#  0.028151102,
#  -0.23645608,
#  0.06612544,
#  -0.28598842,
#  -0.45165315,
#  -0.022623943,
#  -0.08872302,
#  -0.06081677,
#  -0.26913667,
#  -0.19010288,
#  -0.25393653,
#  -0.0647226,
#  -0.23978537,
#  0.03604637,
#  0.17923789,
#  0.14369181,
#  -0.093892455,
#  -0.18943097,
#  0.023279216,
#  -0.21672636,
#  -0.22531413,
#  -0.6191525,
#  0.16888745,
#  -0.32214487,
#  0.10071864,
#  -0.9872922,
#  -0.083790004,
#  -0.13151774,
#  -0.23341669,
#  0.36098295,
#  -0.17357193,
#  -0.033106875,
#  -0.055651087,
#  ...]

# %%
# 30 minutes to run
df_train["embed_1"] = df_train["sen_1"].progress_apply(lambda x: get_bart_embeddings(x))
df_train["embed_2"] = df_train["sen_2"].progress_apply(lambda x: get_bart_embeddings(x))
df_train.tail()
# Out:
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]
#               PairID                                               Text  \
# 5495  ENG-train-5495  A young boy pounding on an anvil.\r\nWoman sit...
# 5496  ENG-train-5496  I love how he recognized his wife tempered his...
# 5497  ENG-train-5497  I actually read a chapter or two beyond that p...
# 5498  ENG-train-5498  A boy gives being in the snow two thumbs up.\r...
# 5499  ENG-train-5499  Perhaps it is strange to think about sex const...
#
#       Score                                              sen_1  \
# 5495    0.0                  A young boy pounding on an anvil
# 5496    0.0  I love how he recognized his wife tempered his...
# 5497    0.0  I actually read a chapter or two beyond that p...
# 5498    0.0       A boy gives being in the snow two thumbs up
# 5499    0.0  Perhaps it is strange to think about sex const...
#
#                                                   sen_2  \
# 5495     Woman sits on the curb talking on a cellphone
# 5496   Torpedo Ink is Viktor s Band of Brothers the ...
# 5497     Lets say she s a blend of two types of beings
# 5498   A satisfied cat is perched beside a crystal l...
# 5499      Few people know how to shoot pool these days
#
#                                                 embed_1  \
# 5495  [0.09755159, -0.4822137, -0.16296929, -0.32676...
# 5496  [0.06294839, 0.14637762, -0.34401453, -0.02745...
# 5497  [0.09683492, 0.39988258, -0.190917, -0.0704128...
# 5498  [0.14005427, -0.30437708, -0.47931513, 0.10546...
# 5499  [-0.27250853, 0.8595137, -0.1390178, -0.141094...
#
#                                                 embed_2
# 5495  [-0.23564994, -0.1651132, -0.373366, 0.2031315...
# 5496  [-0.1694183, -0.31326413, 0.006729871, -0.1742...
# 5497  [0.046493202, 0.18600889, -0.3208649, -0.00230...
# 5498  [0.104509, -0.40117535, -0.71972233, -0.122540...
# 5499  [0.03904477, 0.42368385, -0.16985238, 0.117221...

# %%
# Use cosine similarity between the vectors as a score
df_train["Prediction"] = df_train.apply(lambda x: 1 - spatial.distance.cosine(x["embed_1"], x["embed_2"]), axis=1)
display(df_train.head())

print("Cosine distance, Spearman Correlation:", round(spearmanr(df_train["Score"], df_train["Prediction"])[0],3))
# Out:
#            PairID                                               Text  Score  \
# 0  ENG-train-0000  It that happens, just pull the plug.\r\nif tha...    1.0
# 1  ENG-train-0001  A black dog running through water.\r\nA black ...    1.0
# 2  ENG-train-0002  I've been searchingthe entire abbey for you.\r...    1.0
# 3  ENG-train-0003  If he is good looking and has a good personali...    1.0
# 4  ENG-train-0004  She does not hate you, she is just annoyed wit...    1.0
#
#                                                sen_1  \
# 0                It that happens just pull the plug
# 1                 A black dog running through water
# 2       I ve been searchingthe entire abbey for you
# 3  If he is good looking and has a good personali...
# 4  She does not hate you she is just annoyed with...
#
#                                                sen_2  \
# 0           if that ever happens just pull the plug
# 1         A black dog is running through some water
# 2            I m looking for you all over the abbey
# 3   If he s good looking and a good personality h...
# 4          She doesn t hate you she is just annoyed
#
#                                              embed_1  \
# 0  [-0.11991139, 0.58756006, 0.09463254, -0.03265...
# 1  [0.07583185, -0.46020386, -0.47407135, -0.2750...
# 2  [0.2032519, -0.11944655, -0.024208633, -0.0364...
# 3  [0.11519185, -0.2673091, -0.41681337, -0.41138...
# 4  [0.055690456, 0.37848297, -0.25579396, 0.05901...
#
#                                              embed_2  Prediction
# 0  [-0.20186402, 0.7138717, 0.00923355, -0.136259...    0.927955
# 1  [-0.08202204, -0.42917526, -0.62733215, 0.1499...    0.943377
# 2  [0.06615189, 0.18228194, -0.14900401, 0.113741...    0.901551
# 3  [0.01850178, -0.16432671, -0.46576646, -0.2831...    0.953265
# 4  [0.07870173, 0.19003592, -0.32398522, -0.14323...    0.947812
# Cosine distance, Spearman Correlation: 0.673

# %% [markdown]
# # BERT with Preprocessing

# %%
# Preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

# Function for preprocessing a single sentence
def preprocess_sentence(sentence):
    # Tokenization
    words = word_tokenize(sentence)
    
    # Lowercasing
    words = [word.lower() for word in words]
    
    # Removing stop words and punctuation
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalnum() and word not in stop_words]
    
    # Stemming (optional)
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    
    # Join the words back into a sentence
    processed_sentence = ' '.join(words)
    
    return processed_sentence
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dchro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dchro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_train["sen_1_processed"] = df_train["sen_1"].progress_apply(lambda x: preprocess_sentence(x))
df_train["sen_2_processed"] = df_train["sen_2"].progress_apply(lambda x: preprocess_sentence(x))
# Out:
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]

# %%
# 30 minutes to run
df_train["embed_1_processed"] = df_train["sen_1_processed"].progress_apply(lambda x: get_bart_embeddings(x))
df_train["embed_2_processed"] = df_train["sen_2_processed"].progress_apply(lambda x: get_bart_embeddings(x))
df_train.head()
# Out:
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]
#            PairID                                               Text  Score  \
# 0  ENG-train-0000  It that happens, just pull the plug.\r\nif tha...    1.0
# 1  ENG-train-0001  A black dog running through water.\r\nA black ...    1.0
# 2  ENG-train-0002  I've been searchingthe entire abbey for you.\r...    1.0
# 3  ENG-train-0003  If he is good looking and has a good personali...    1.0
# 4  ENG-train-0004  She does not hate you, she is just annoyed wit...    1.0
#
#                                                sen_1  \
# 0                It that happens just pull the plug
# 1                 A black dog running through water
# 2       I ve been searchingthe entire abbey for you
# 3  If he is good looking and has a good personali...
# 4  She does not hate you she is just annoyed with...
#
#                                                sen_2  \
# 0           if that ever happens just pull the plug
# 1         A black dog is running through some water
# 2            I m looking for you all over the abbey
# 3   If he s good looking and a good personality h...
# 4          She doesn t hate you she is just annoyed
#
#                                              embed_1  \
# 0  [-0.11991139, 0.58756006, 0.09463254, -0.03265...
# 1  [0.07583185, -0.46020386, -0.47407135, -0.2750...
# 2  [0.2032519, -0.11944655, -0.024208633, -0.0364...
# 3  [0.11519185, -0.2673091, -0.41681337, -0.41138...
# 4  [0.055690456, 0.37848297, -0.25579396, 0.05901...
#
#                                              embed_2  Prediction  \
# 0  [-0.20186402, 0.7138717, 0.00923355, -0.136259...    0.927955
# 1  [-0.08202204, -0.42917526, -0.62733215, 0.1499...    0.943377
# 2  [0.06615189, 0.18228194, -0.14900401, 0.113741...    0.901551
# 3  [0.01850178, -0.16432671, -0.46576646, -0.2831...    0.953265
# 4  [0.07870173, 0.19003592, -0.32398522, -0.14323...    0.947812
#
#                                     sen_1_processed  \
# 0                                  happen pull plug
# 1                               black dog run water
# 2                           searchingth entir abbey
# 3  good look good person might straight like bisexu
# 4                                        hate annoy
#
#                                 sen_2_processed  \
# 0                         ever happen pull plug
# 1                           black dog run water
# 2                                    look abbey
# 3  good look good person might straight like bi
# 4                                    hate annoy
#
#                                    embed_1_processed  \
# 0  [0.103418395, 0.25857654, -0.37682882, 0.00904...
# 1  [0.09684483, -0.4108062, -0.8034242, -0.517948...
# 2  [0.21051075, -0.1410264, -0.4149496, -0.063323...
# 3  [-0.04059158, 0.07944068, -0.61094266, -0.3878...
# 4  [0.09215502, 0.076552846, -0.5966915, -0.14657...
#
#                                    embed_2_processed
# 0  [0.25954938, 0.4175096, -0.6953409, -0.0292761...
# 1  [0.09684483, -0.4108062, -0.8034242, -0.517948...
# 2  [0.34044912, -0.2988389, -0.49687386, -0.30214...
# 3  [-0.020841777, 0.09724368, -0.7336934, -0.6219...
# 4  [0.09215502, 0.076552846, -0.5966915, -0.14657...

# %%
# Use cosine similarity between the vectors as a score
df_train["Prediction_processed"] = df_train.apply(lambda x: 1 - spatial.distance.cosine(x["embed_1_processed"], x["embed_2_processed"]), axis=1)
# display(df_train.head())

print("Cosine distance, Spearman Correlation:", round(spearmanr(df_train["Score"], df_train["Prediction_processed"])[0],3))
# Out:
# Cosine distance, Spearman Correlation: 0.572
